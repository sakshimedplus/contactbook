# %%
  
def choose():
    dicti={}
    while True:           
        print('------------------------------------------------------------')
        print ('chose option ')
        print('1=>add new contact')
        print('2=>delete contact')
        print('4=>search contact')
        print('5=>display all contact number')
        
        print('------------------------------------------------------------')
        a=int(input('option'))
        if a==1:
            n=input('name')
            p=int(input('phoneno'))
            if n in dicti.keys():
                print('error cont already exist')
            else:
                dicti.update({n:p})
                print('contact updated')
            
        elif a==2:
            n=input('name')
            if n in dicti.keys():
                dicti.pop(name)
                print('contact updated')
            else:
                print('error contact not found')

        elif a==4:
            n=input('name')
            if n in dicti.keys():
                print(n,":", dicti[n])
            else:
                print('error contact not found')
        elif a==5:
            for x in dicti:
                print(x, ":", dicti[x])
        elif a==6:
            print("end")
            break
        else:
            print("invalid choice")
choose()
# Out:
# ------------------------------------------------------------
# chose option
# 1=>add new contact
# 2=>delete contact
# 4=>search contact
# 5=>display all contact number
# ------------------------------------------------------------
# option1
# namesaa
# phoneno57547
# contact updated
# ------------------------------------------------------------
# chose option
# 1=>add new contact
# 2=>delete contact
# 4=>search contact
# 5=>display all contact number
# ------------------------------------------------------------
# option5
# saa : 57547
# ------------------------------------------------------------
# chose option
# 1=>add new contact
# 2=>delete contact
# 4=>search contact
# 5=>display all contact number
# ------------------------------------------------------------
# option4
# namesaa
# saa : 57547
# ------------------------------------------------------------
# chose option
# 1=>add new contact
# 2=>delete contact
# 4=>search contact
# 5=>display all contact number
# ------------------------------------------------------------
